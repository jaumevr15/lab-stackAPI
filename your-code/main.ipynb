# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
from stackapi import StackAPI
import requests
import pandas as pd
SITE = StackAPI('stackoverflow')

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
posts = SITE.fetch('posts',fromdate=1570547602, todate=1573226002)
posts
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 118,
#     'user_id': 8552543,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/IcebT.gif?s=128&g=1',
#     'display_name': 'tr53',
#     'link': 'https://stackoverflow.com/users/8552543/tr53'},
#    'score': 0,
#    'last_edit_date': 1573226029,
#    'last_activity_date': 1573226029,
#    'creation_date': 1573224703,
#    'post_type': 'answer',
#    'post_id': 58768838,
#    'link': 'https://stackoverflow.com/a/58768838'},
#   {'owner': {'reputation': 118,
#     'user_id': 8552543,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/IcebT.gif?s=128&g=1',
#     'display_name': 'tr53',
#     'link': 'https://stackoverflow.com/users/8552543/tr53'},
#    'score': -1,
#    'last_edit_date': 1573225836,
#    'last_activity_date': 1573226029,
#    'creation_date': 1573144193,
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
topvoted = SITE.fetch('questions', creation_date=21573171200, score = 5, tags='python')
topvoted
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['c++', 'cgal'],
#    'owner': {'reputation': 1,
#     'user_id': 11175624,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/b895895313feee0b1004cf4d4bef736a?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Amit Singh',
#     'link': 'https://stackoverflow.com/users/11175624/amit-singh'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1573226730,
#    'creation_date': 1573226730,
#    'question_id': 58769402,
#    'link': 'https://stackoverflow.com/questions/58769402/cgal-delaunay-triangulation-of-immersed-manifolds',
#    'title': 'CGAL Delaunay Triangulation of immersed manifolds'},
#   {'tags': ['sql', 'ssas', 'mdx', 'olap'],
#    'owner': {'reputation': 346,
#     'user_id': 7290845,
#     'user_type': 'registered',
# ...

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
ans_67 = SITE.fetch('answers', answer_id=6784)
ans_64 = SITE.fetch('answers', answer_id=6473)
# Out:
# ---------------------------------------------------------------------------
# StackAPIError                             Traceback (most recent call last)
# <ipython-input-28-29b7bdc78da5> in <module>
# ----> 1 ans_67 = SITE.fetch('answers', answer_id=6784)
#       2 ans_64 = SITE.fetch('answers', answer_id=6473)
#
# ~\Anaconda3\lib\site-packages\stackapi\stackapi.py in fetch(self, endpoint, page, key, filter, **kwargs)
#     196                 code = response["error_name"]
#     197                 message = response["error_message"]
# --> 198                 raise StackAPIError(self._previous_call, error, code, message)
#     199             except KeyError:
#     200                 pass  # This means there is no error
#
# StackAPIError: ('https://api.stackexchange.com/2.2/answers/?pagesize=100&page=1&filter=default&answer_id=6784&site=stackoverflow', 502, 'throttle_violation', 'too many requests from this IP, more requests available in 72931 seconds')
